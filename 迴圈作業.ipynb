# %% [markdown]
# <a href="https://colab.research.google.com/github/ChengHan16/Cs4high_4080E036/blob/master/%E8%BF%B4%E5%9C%88%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for name in ['Christopher', 'Susan']:
	print(name)
# Out:
# Christopher
# Susan

# %%
for index in range(0, 2):
	print(index)
# Out:
# 0
# 1

# %%
names = ['Christopher', 'Susan']
index = 0
while index < len(names):   #判斷條件
	print(names[index]) 
	# Change the condition!!
	index = index + 1
# Out:
# Christopher
# Susan

# %%
price =10

if price >= 1.00:
	tax = .07
	print(tax)
else:
	tax = 0
	print(tax)
# Out:
# 0.07

# %%
if price >= 1.00:
	tax = .07
	print(tax)
else:
	tax = 0
	print(tax)
# Out:
# 0.07

# %%
if price >= 1.00:
	tax = .07
else:
	tax = 0
print(tax)
# Out:
# 0.07

# %%
country = 'CANADA'
if country == 'canada':
    print('Oh look a Canadian')    
else:
    print('You are not from Canada')
# Out:
#   File "<ipython-input-35-092087bd1698>", line 3
#     print('Oh look a Canadian')
#     ^
# SyntaxError: invalid syntax

# %%
province="country"

if province == 'Alberta':
	tax = 0.05
elif province == 'Nunavut':
	tax = 0.05
elif province == 'Ontario':
	tax = 0.13
else:
	tax = 0.15
  print(province)
# Out:
#   File "<ipython-input-44-28ab12fa134c>", line 11
#     print(province)
#                    ^
# IndentationError: unindent does not match any outer indentation level

# %%
if province == 'Alberta' \ or province == 'Nunavut':
	tax = 0.05
elif province == 'Ontario':
	tax = 0.13
else:
	tax = 0.15
  print(province)
# Out:
#   File "<ipython-input-47-cb4511fc1dc0>", line 1
#     if province == ('Alberta' \ or province == 'Nunavut':)
#                                                           ^
# SyntaxError: unexpected character after line continuation character

# %%
print("hello!")
print(3*2*(17-2.1))
print("abc"+"def")
word = "art"
print(word.replace("r", "n"))
# Out:
# hello!
# 89.4
# abcdef
# ant

# %%
a= 1
b= 2
c = a/b
print(a, "/", b, "=", c) 
add = str(a)+"/"+str(b)+"="+str(c)
print(add)
# Out:
# (1, '/', 2, '=', 0)
# 1/2=0
