# %% [markdown]
# <a href="https://colab.research.google.com/github/ChengHan16/Cs4high_4080E036/blob/master/Find.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = input('請輸入字串')

p = s.split(',')
print(int(p[0]) + int(p[len(p) - 1]))
# Out:
# 請輸入字串100,200
# 300

# %%
str1 = "this is string example....wow!!!"
str2 = "exam"

print(str1.find(str2))
print(str1.find(str2, 10))
print(str1.find(str2, 40))
# Out:
# 15
# 15
# -1
