# %% [markdown]
# <a href="https://colab.research.google.com/github/ChengHan16/Cs4high_4080E036/blob/master/Python%E6%9C%9F%E4%B8%AD%E7%B7%B4%E7%BF%92.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("3*2*(17-2)")
# Out:
# 3*2*(17-2)

# %%
print(3*2*(17-2))
# Out:
# 90

# %%
print("abc""+""def")
# Out:
# abc+def

# %%
print("abc"+"def")
# Out:
# abcdef

# %%
word = "arttarataaa"
print(word.replace("a", "z",3))
# Out:
# zrttzrztaaa

# %%
word = "arttarataaa"
print(word.replace("a", "z"))
# Out:
# zrttzrztzzz

# %%
names = ['龍', '聖']
index = 0

while index < len(names):
    name = names[index]
    print(name)
    index = index + 1
# Out:
# 龍
# 聖

# %%
sum=0

for x in range(1,101):
  sum +=x
  
print(sum)
# Out:
# 5050

# %%
sum=0

for x in range(1,101,2):
  sum +=x
  
print(sum)
# Out:
# 2500

# %%
total=1

for x in range(1,101,2):
  total *=x
  
print(total)
# Out:
# 2725392139750729502980713245400918633290796330545803413734328823443106201171875

# %%
sum=1

for x in range(1,101,2):
  sum *=x
  
print(sum)
# Out:
# 2725392139750729502980713245400918633290796330545803413734328823443106201171875

# %%
sum = 0
x=1

while x < 101:
  sum +=x
  x = x+1
  # x += 1
  
print(sum)
# Out:
# 5050

# %%
sum = 0
x=1

while x < 101:
  sum +=x
  x = x+2
  # x += 1
  
print(sum)
# Out:
# 2500

# %%
total = 1
x=1

while x < 101:
  total *=x
  x = x+2     # x += 2
  
print(total)
# Out:
# 2725392139750729502980713245400918633290796330545803413734328823443106201171875

# %%
round(3.49)
# Out:
# 3

# %%
round(3.51)
# Out:
# 4

# %%
divmod(3,5)
# Out:
# (0, 3)

# %%
divmod(5,3)
# Out:
# (1, 2)

# %%
divmod(-5,3)
# Out:
# (-2, 1)

# %%
divmod(2,4)
# Out:
# (0, 2)

# %%
hex(7)
# Out:
# '0x7'
