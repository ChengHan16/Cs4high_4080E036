# %% [markdown]
# <a href="https://colab.research.google.com/github/ChengHan16/Cs4high_4080E036/blob/master/%E2%80%9CPython_1_IO_ipynb%E2%80%9D09_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 輸入與輸出(Input and Output)2019/09/19
#
# 單元學習目標:
#
# python輸入:input(), raw_input()
#
# python輸出: print()
#
# python格式化輸出技術

# %% [markdown]
# ## 基本輸入:讀取使用者的輸入
# ```
# 使用input時，會從標準輸入(stdin)中讀取輸入資料
# 這些資料是string字串型態{重要}
# ```
#
# stdin==Standard Input

# %%
x = input('輸入你的名字:')
print('哈囉, ' + x)
# Out:
# 輸入你的名字:承翰
# 哈囉, 承翰

# %%
a = input("請輸入：")
a
# Out:
# 請輸入：100
# '100'

# %% [markdown]
# ###  Python內建的type()函數可以顯示資料型態

# %% [markdown]
# str==string==字串資料型態

# %%
type(a)
# Out:
# str

# %%
a = input("請輸入:")
a
b=a+1
b
# Out:
# 請輸入:100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-a47b6003bb46> in <module>()
#       1 a = input("請輸入:")
#       2 a
# ----> 3 b=a+1
#       4 b
#
# TypeError: must be str, not int

# %% [markdown]
# TypeError ==資料型態錯誤
#
# type==資料型態==data type
#
# 輸入數字 100
#
# input ()
#
# 是字串100 不是數字

# %% [markdown]
# ### 錯誤的做法：請指出底下程式的錯誤

# %% [markdown]
# ## 基本輸入:讀取使用者輸入的整數
#
# 使用eval()函數

# %%
c = int(input("請輸入: "))
type(c)
# Out:
# 請輸入: 100
# int

# %% [markdown]
# eval 函數(變數字)

# %%
a = eval(input("請輸入："))
type(a)
# Out:
# 請輸入：100
# int

# %%
a = eval(input("請輸入："))
a
# Out:
# 請輸入：100
# 100

# %%
b=a+1
b
# Out:
# 101

# %% [markdown]
# ## 超級重要:可以一次輸入多（兩）個資料

# %%
a,b = eval(input("請輸入兩個數位："))
a,b
# Out:
# 請輸入兩個數位：11,22
# (11, 22)

# %% [markdown]
# ### 高階技巧:

# %%
x, y, z = [int(x) for x in input("Enter three value: ").split()] 
print("First Number is: ", x) 
print("Second Number is: ", y) 
print("Third Number is: ", z) 
print()
# Out:
# Enter three value: 2 3 4
# First Number is:  2
# Second Number is:  3
# Third Number is:  4

# %%
x, y, z = [int(x) for x in input("Enter three value: ").split(",")] 
print("First Number is: ", x) 
print("Second Number is: ", y) 
print("Third Number is: ", z) 
print()

# %%
a, b = input("Enter a two value: ").split() 
print("First number is {} and second number is {}".format(a, b)) 
print()
# Out:
# Enter a two value: 1 2
# First number is 1 and second number is 2

# %%
# Out:
# '0xff'
